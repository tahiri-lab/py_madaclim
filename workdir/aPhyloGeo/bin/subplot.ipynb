# %% [markdown]
# Figure - Anglais

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

df = pd.read_csv(r'..\data\data3.csv')
columns = ['Lat_start_dec', 'Long_start_dec', 'Depth_start', 'Wind_speed_start', 'Watertemp_ground', 'O2-saturation_ground']
column_names = ['Lat start (DD)', 'Long start (DD)', 'Depth start (m)', 'Windspeed start (m/s)', 'Watertemp ground (°C)', 'O2-saturation ground (mg/L)']
fig, axs = plt.subplots(nrows=2, ncols=math.ceil(len(columns)/2), figsize=(8*math.ceil(len(columns)/2), 14), dpi=120)
palette = sns.color_palette("hls", len(columns))

for i, column in enumerate(columns):
    row = i // math.ceil(len(columns)/2)
    col = i % math.ceil(len(columns)/2)
    sns.violinplot(y=df[column], ax=axs[row][col], color=palette[i], orient='v', linewidth=1)
    axs[row][col].set_xlabel("")  
    axs[row][col].set_ylabel(column_names[i], fontsize=14)  
    axs[row][col].tick_params(axis='both', labelsize=14)  

    mean = df[column].mean()
    median = df[column].median()
    std_dev = df[column].std()
    quartiles = df[column].quantile([0.25, 0.75]).values
    
    x_center = axs[row][col].collections[0].get_paths()[0].vertices[:, 0].mean()

    # Plot the median line only across the middle of the violin plot
    axs[row][col].plot([x_center - 0.01, x_center + 0.01], [median, median], color='white', linestyle='-', linewidth=2)


plt.tight_layout(rect=[0, 0.03, 1, 0.95])  
plt.subplots_adjust(hspace=0.1, wspace=0.13)  # Reduced hspace and wspace

plt.savefig('../images/figure1.jpg', format='jpg', dpi=300)
plt.show()

# %% [markdown]
# Figure - Francais
#
# - Lat start (DD) = Lat début (DD);
# - Long start = Long début (DD);
# - Depth start (DD) = Profondeur début (m);
# - Windspeed start (m/s) = Vitesse du vent début (m/s);
# - Watertemp ground (°C) = Température de l'eau (°C);
# - O2-saturation ground = Concentration d'O2 de l'eau.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

df = pd.read_csv(r'..\data\data3.csv')
columns = ['Lat_start_dec', 'Long_start_dec', 'Depth_start', 'Wind_speed_start', 'Watertemp_ground', 'O2-saturation_ground']
column_names = ['Lat début (DD)', 'Long début (DD)', 'Profondeur début (m)', 'Vitesse du vent début (m/s)', 'Température de l\'eau(°C)', 'Concentration d\'O2 de l\'eau (mg/L)']
fig, axs = plt.subplots(nrows=2, ncols=math.ceil(len(columns)/2), figsize=(8*math.ceil(len(columns)/2), 14), dpi=120)
palette = sns.color_palette("hls", len(columns))

for i, column in enumerate(columns):
    row = i // math.ceil(len(columns)/2)
    col = i % math.ceil(len(columns)/2)
    sns.violinplot(y=df[column], ax=axs[row][col], color=palette[i], orient='v', linewidth=1)
    axs[row][col].set_xlabel("")  
    axs[row][col].set_ylabel(column_names[i], fontsize=14)  
    axs[row][col].tick_params(axis='both', labelsize=14)  

    mean = df[column].mean()
    median = df[column].median()
    std_dev = df[column].std()
    quartiles = df[column].quantile([0.25, 0.75]).values
    
    x_center = axs[row][col].collections[0].get_paths()[0].vertices[:, 0].mean()

    # Plot the median line only across the middle of the violin plot
    axs[row][col].plot([x_center - 0.01, x_center + 0.01], [median, median], color='white', linestyle='-', linewidth=2)


plt.tight_layout(rect=[0, 0.03, 1, 0.95])  
plt.subplots_adjust(hspace=0.1, wspace=0.13)  # Reduced hspace and wspace

plt.savefig('../images/figure1_fr.jpg', format='jpg', dpi=300)
plt.show()

# %% [markdown]
# 1. "Espèces" et "Nombre d'espèces"
#
# 2. "Species" et "Number of species"

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
 
df = pd.read_csv(r'../data/data3.csv')
df
# Out:
#         Sampleid           Family        Genus         Scientific_name  \
# 0    ICE1-Bod001      Bodotriidae    Cyclaspis  Cyclaspis longicaudata
# 1    ICE1-Bod003      Bodotriidae          NaN                     NaN
# 2    ICE1-Bod004      Bodotriidae    Bathycuma   Bathycuma brevirostre
# 3    ICE1-Cer002  Ceratocumatidae    Cimmerius   Cimmerius reticulatus
# 4    ICE1-Cer003  Ceratocumatidae    Cimmerius   Cimmerius reticulatus
# ..           ...              ...          ...                     ...
# 57   ICE1-Leu001       Leuconidae       Leucon        Leucon profundus
# 58   ICE1-Leu004       Leuconidae       Leucon        Leucon profundus
# 59   ICE1-Leu005       Leuconidae       Leucon         Leucon pallidus
# 60   ICE1-Leu009       Leuconidae       Leucon         Leucon pallidus
# 61  ICE1-Nann005        Astacidae  Campylaspis                     NaN
#
#      Habitat          Sector Water_mass   Sediment  Lat_start_dec  \
# ...

# %%
# Create a new figure for the frequency plot
fig, ax = plt.subplots(figsize=(13, 8))  # Increased figure size
 
# Create a color palette
palette = sns.color_palette("hls", len(df['Scientific_name'].unique()))
 
# Create a countplot with the color palette
sns.countplot(y='Scientific_name', data=df, order=df['Scientific_name'].value_counts().index, palette=palette)
 
# Set the labels and title
ax.set_xlabel('Number of species', fontsize=13)
ax.set_ylabel('Species', fontsize=13, labelpad=20)  # Adjusted label padding
ax.tick_params(axis='both', labelsize=13)  # Adjust tick label size
 
# Add statistics
total = len(df)
counts = df['Scientific_name'].value_counts()
mean = counts.mean()
median = counts.median()
mode = counts.mode()[0]
 
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_width()/total)
    x = p.get_x() + p.get_width() + 0.02
    y = p.get_y() + p.get_height()/2
    ax.annotate(percentage, (x, y), xytext=(15, 0), textcoords='offset points', fontsize=13)
 
# Add mean, median, and mode to the plot
# ax.annotate(f'Mean: {mean:.2f}', xy=(0.75, 0.95), xycoords='axes fraction')
# ax.annotate(f'Median: {median:.2f}', xy=(0.75, 0.90), xycoords='axes fraction')
# ax.annotate(f'Mode: {mode:.2f}', xy=(0.75, 0.85), xycoords='axes fraction')
 
# Add axes
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
 
plt.tight_layout()  # Adjust layout to prevent overlap
 
plt.savefig(r'../images/figure2.jpg', format='jpg', dpi=300)  # Save the figure as a jpg file
 
# Show the plot
plt.show()

# %%
# Create a new figure for the frequency plot
fig, ax = plt.subplots(figsize=(13, 8))  # Increased figure size
 
# Create a color palette
palette = sns.color_palette("hls", len(df['Scientific_name'].unique()))
 
# Create a countplot with the color palette
sns.countplot(y='Scientific_name', data=df, order=df['Scientific_name'].value_counts().index, palette=palette)
 
# Set the labels and title
ax.set_xlabel('Nombre d\'espèces', fontsize=13)
ax.set_ylabel('Espèces', fontsize=13, labelpad=20)  # Adjusted label padding
ax.tick_params(axis='both', labelsize=13)  # Adjust tick label size
 
# Add statistics
total = len(df)
counts = df['Scientific_name'].value_counts()
mean = counts.mean()
median = counts.median()
mode = counts.mode()[0]
 
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_width()/total)
    x = p.get_x() + p.get_width() + 0.02
    y = p.get_y() + p.get_height()/2
    ax.annotate(percentage, (x, y), xytext=(15, 0), textcoords='offset points', fontsize=13)
 
# Add mean, median, and mode to the plot
# ax.annotate(f'Mean: {mean:.2f}', xy=(0.75, 0.95), xycoords='axes fraction')
# ax.annotate(f'Median: {median:.2f}', xy=(0.75, 0.90), xycoords='axes fraction')
# ax.annotate(f'Mode: {mode:.2f}', xy=(0.75, 0.85), xycoords='axes fraction')
 
# Add axes
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
 
plt.tight_layout()  # Adjust layout to prevent overlap
 
plt.savefig(r'../images/figure2_fr.jpg', format='jpg', dpi=300)  # Save the figure as a jpg file
 
# Show the plot
plt.show()
