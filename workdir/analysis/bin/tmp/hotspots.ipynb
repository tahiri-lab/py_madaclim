# %%
# !pip install pysal
# Out:
# Collecting pysal
#   Downloading pysal-24.7-py3-none-any.whl.metadata (16 kB)
# Collecting beautifulsoup4>=4.10 (from pysal)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: geopandas>=0.10.0 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pysal) (0.13.2)
# Requirement already satisfied: numpy>=1.22 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pysal) (2.0.0)
# Requirement already satisfied: packaging>=22 in c:\users\adm1\appdata\roaming\python\python312\site-packages (from pysal) (24.1)
# Requirement already satisfied: pandas>=1.4 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pysal) (2.2.2)
# Requirement already satisfied: platformdirs>=2.0.2 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pysal) (4.2.2)
# Requirement already satisfied: requests>=2.27 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pysal) (2.32.3)
# Requirement already satisfied: scipy>=1.8 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pysal) (1.14.1)
# Requirement already satisfied: shapely>=2.0.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pysal) (2.0.4)
# Requirement already satisfied: scikit-learn>=1.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pysal) (1.5.2)
# Collecting libpysal>=4.12.0 (from pysal)
#   Downloading libpysal-4.12.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting access>=1.1.9 (from pysal)
#   Downloading access-1.1.9-py3-none-any.whl.metadata (2.4 kB)
# Collecting esda>=2.6.0 (from pysal)
#   Downloading esda-2.6.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting giddy>=2.3.5 (from pysal)
#   Downloading giddy-2.3.5-py3-none-any.whl.metadata (6.4 kB)
# Collecting inequality>=1.0.1 (from pysal)
#   Downloading inequality-1.0.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting pointpats>=2.5.0 (from pysal)
#   Downloading pointpats-2.5.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting segregation>=2.5 (from pysal)
#   Downloading segregation-2.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting spaghetti>=1.7.6 (from pysal)
#   Downloading spaghetti-1.7.6-py3-none-any.whl.metadata (12 kB)
# Collecting mgwr>=2.2.1 (from pysal)
#   Downloading mgwr-2.2.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting momepy>=0.7.2 (from pysal)
#   Downloading momepy-0.8.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting spglm>=1.1.0 (from pysal)
#   Downloading spglm-1.1.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting spint>=1.0.7 (from pysal)
#   Downloading spint-1.0.7.tar.gz (28 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting spreg>=1.5.0 (from pysal)
#   Downloading spreg-1.7-py3-none-any.whl.metadata (1.7 kB)
# Collecting spvcm>=0.3.0 (from pysal)
#   Downloading spvcm-0.3.0.tar.gz (5.7 MB)
#      ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#      --------- ------------------------------ 1.3/5.7 MB 7.4 MB/s eta 0:00:01
#      ------------------ --------------------- 2.6/5.7 MB 6.3 MB/s eta 0:00:01
#      ----------------------------- ---------- 4.2/5.7 MB 6.6 MB/s eta 0:00:01
#      ------------------------------------ --- 5.2/5.7 MB 6.6 MB/s eta 0:00:01
#      ---------------------------------------- 5.7/5.7 MB 6.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting tobler>=0.11.2 (from pysal)
#   Downloading tobler-0.11.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting mapclassify>=2.7.0 (from pysal)
#   Downloading mapclassify-2.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting splot>=1.1.5.post1 (from pysal)
#   Downloading splot-1.1.7-py3-none-any.whl.metadata (8.9 kB)
# Collecting spopt>=0.6.1 (from pysal)
#   Downloading spopt-0.6.1-py3-none-any.whl.metadata (10 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.10->pysal)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: fiona>=1.8.19 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from geopandas>=0.10.0->pysal) (1.9.6)
# Requirement already satisfied: pyproj>=3.0.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from geopandas>=0.10.0->pysal) (3.6.1)
# Collecting quantecon>=0.4.7 (from giddy>=2.3.5->pysal)
#   Downloading quantecon-0.7.2-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: networkx>=2.7 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from mapclassify>=2.7.0->pysal) (3.3)
# Requirement already satisfied: tqdm>=4.63.0 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from momepy>=0.7.2->pysal) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adm1\appdata\roaming\python\python312\site-packages (from pandas>=1.4->pysal) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.4->pysal) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.4->pysal) (2024.1)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pointpats>=2.5.0->pysal) (3.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.27->pysal) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.27->pysal) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.27->pysal) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.27->pysal) (2024.6.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.1->pysal) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.1->pysal) (3.5.0)
# Collecting deprecation (from segregation>=2.5->pysal)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: seaborn in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from segregation>=2.5->pysal) (0.12.2)
# Collecting numba (from segregation>=2.5->pysal)
#   Downloading numba-0.60.0-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting rtree>=1.0 (from spaghetti>=1.7.6->pysal)
#   Downloading Rtree-1.3.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Collecting pulp>=2.7 (from spopt>=0.6.1->pysal)
#   Downloading PuLP-2.9.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: rasterio in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from tobler>=0.11.2->pysal) (1.3.10)
# Requirement already satisfied: statsmodels in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from tobler>=0.11.2->pysal) (0.14.3)
# Collecting rasterstats (from tobler>=0.11.2->pysal)
#   Downloading rasterstats-0.20.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.19->geopandas>=0.10.0->pysal) (23.2.0)
# Requirement already satisfied: click~=8.0 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.19->geopandas>=0.10.0->pysal) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.19->geopandas>=0.10.0->pysal) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.19->geopandas>=0.10.0->pysal) (0.7.2)
# Requirement already satisfied: six in c:\users\adm1\appdata\roaming\python\python312\site-packages (from fiona>=1.8.19->geopandas>=0.10.0->pysal) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.6->pointpats>=2.5.0->pysal) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.6->pointpats>=2.5.0->pysal) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.6->pointpats>=2.5.0->pysal) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.6->pointpats>=2.5.0->pysal) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.6->pointpats>=2.5.0->pysal) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.6->pointpats>=2.5.0->pysal) (3.1.2)
# Collecting sympy (from quantecon>=0.4.7->giddy>=2.3.5->pysal)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba->segregation>=2.5->pysal)
#   Downloading llvmlite-0.43.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: colorama in c:\users\adm1\appdata\roaming\python\python312\site-packages (from tqdm>=4.63.0->momepy>=0.7.2->pysal) (0.4.6)
# Requirement already satisfied: affine in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from rasterio->tobler>=0.11.2->pysal) (2.4.0)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from rasterio->tobler>=0.11.2->pysal) (1.4.7)
# Requirement already satisfied: setuptools in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from rasterio->tobler>=0.11.2->pysal) (75.1.0)
# Collecting simplejson (from rasterstats->tobler>=0.11.2->pysal)
#   Downloading simplejson-3.19.3-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from statsmodels->tobler>=0.11.2->pysal) (0.5.6)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->quantecon>=0.4.7->giddy>=2.3.5->pysal)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading pysal-24.7-py3-none-any.whl (17 kB)
# Downloading access-1.1.9-py3-none-any.whl (21 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Downloading esda-2.6.0-py3-none-any.whl (135 kB)
# Downloading giddy-2.3.5-py3-none-any.whl (61 kB)
# Downloading inequality-1.0.1-py3-none-any.whl (15 kB)
# Downloading libpysal-4.12.1-py3-none-any.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------- ----------------- 1.6/2.8 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 7.4 MB/s eta 0:00:00
# Downloading mapclassify-2.8.1-py3-none-any.whl (59 kB)
# Downloading mgwr-2.2.1-py3-none-any.whl (47 kB)
# Downloading momepy-0.8.1-py3-none-any.whl (347 kB)
# Downloading pointpats-2.5.1-py3-none-any.whl (59 kB)
# Downloading segregation-2.5-py3-none-any.whl (141 kB)
# Downloading spaghetti-1.7.6-py3-none-any.whl (53 kB)
# Downloading spglm-1.1.0-py3-none-any.whl (41 kB)
# Downloading splot-1.1.7-py3-none-any.whl (39 kB)
# Downloading spopt-0.6.1-py3-none-any.whl (243 kB)
# Downloading spreg-1.7-py3-none-any.whl (372 kB)
# Downloading tobler-0.11.3-py3-none-any.whl (28 kB)
# Downloading PuLP-2.9.0-py3-none-any.whl (17.7 MB)
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/17.7 MB 7.4 MB/s eta 0:00:03
#    ------ --------------------------------- 2.9/17.7 MB 7.0 MB/s eta 0:00:03
#    --------- ------------------------------ 4.2/17.7 MB 6.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.8/17.7 MB 6.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 7.1/17.7 MB 6.8 MB/s eta 0:00:02
#    ------------------ --------------------- 8.4/17.7 MB 6.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 10.0/17.7 MB 6.9 MB/s eta 0:00:02
#    ------------------------- -------------- 11.3/17.7 MB 6.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 12.6/17.7 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 13.9/17.7 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.2/17.7 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------- -- 16.5/17.7 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  17.3/17.7 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 17.7/17.7 MB 6.5 MB/s eta 0:00:00
# Downloading quantecon-0.7.2-py3-none-any.whl (215 kB)
# Downloading numba-0.60.0-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------------- -------------------- 1.3/2.7 MB 6.7 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 6.3 MB/s eta 0:00:00
# Downloading Rtree-1.3.0-py3-none-win_amd64.whl (377 kB)
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading rasterstats-0.20.0-py3-none-any.whl (17 kB)
# Downloading llvmlite-0.43.0-cp312-cp312-win_amd64.whl (28.1 MB)
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    - -------------------------------------- 1.3/28.1 MB 7.4 MB/s eta 0:00:04
#    --- ------------------------------------ 2.6/28.1 MB 6.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 3.9/28.1 MB 6.5 MB/s eta 0:00:04
#    ------- -------------------------------- 5.2/28.1 MB 6.5 MB/s eta 0:00:04
#    --------- ------------------------------ 6.8/28.1 MB 6.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 8.1/28.1 MB 6.5 MB/s eta 0:00:04
#    -------------- ------------------------- 10.0/28.1 MB 6.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 11.3/28.1 MB 6.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 12.6/28.1 MB 6.7 MB/s eta 0:00:03
#    -------------------- ------------------- 14.2/28.1 MB 6.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 15.7/28.1 MB 6.7 MB/s eta 0:00:02
#    ------------------------ --------------- 17.0/28.1 MB 6.7 MB/s eta 0:00:02
#    -------------------------- ------------- 18.4/28.1 MB 6.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 19.9/28.1 MB 6.8 MB/s eta 0:00:02
#    ------------------------------ --------- 21.5/28.1 MB 6.8 MB/s eta 0:00:01
#    -------------------------------- ------- 23.1/28.1 MB 6.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.6/28.1 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------- -- 26.2/28.1 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  27.5/28.1 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 6.7 MB/s eta 0:00:00
# Downloading simplejson-3.19.3-cp312-cp312-win_amd64.whl (75 kB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.2 MB 5.6 MB/s eta 0:00:01
#    --------------- ------------------------ 2.4/6.2 MB 5.8 MB/s eta 0:00:01
#    ------------------------- -------------- 3.9/6.2 MB 6.3 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 6.4 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 6.0 MB/s eta 0:00:00
# Building wheels for collected packages: spint, spvcm
#   Building wheel for spint (pyproject.toml): started
#   Building wheel for spint (pyproject.toml): finished with status 'done'
#   Created wheel for spint: filename=spint-1.0.7-py3-none-any.whl size=31367 sha256=6b21126e668bf4e01323f6d7c1998c6caa5efa3fe09d826bbea3f87802ca77e0
#   Stored in directory: c:\users\adm1\appdata\local\pip\cache\wheels\d9\82\ea\d31b72061cd6dc1760ec44a1d3e74408b1e6ca590a3361d3f9
#   Building wheel for spvcm (pyproject.toml): started
#   Building wheel for spvcm (pyproject.toml): finished with status 'done'
#   Created wheel for spvcm: filename=spvcm-0.3.0-py3-none-any.whl size=5777207 sha256=b791ea5f9d35a8d33355544f1e774076c3d5438df80f5aa19fecfd39c5f81540
#   Stored in directory: c:\users\adm1\appdata\local\pip\cache\wheels\38\00\c6\6725ef15ae08b8c868bbd3ee9829f0ac9d26caebc81051db42
# Successfully built spint spvcm
# Installing collected packages: mpmath, sympy, soupsieve, simplejson, rtree, pulp, llvmlite, deprecation, numba, beautifulsoup4, quantecon, mapclassify, rasterstats, libpysal, access, tobler, spreg, segregation, pointpats, momepy, inequality, esda, spvcm, spglm, spaghetti, giddy, spopt, splot, spint, mgwr, pysal
# Successfully installed access-1.1.9 beautifulsoup4-4.12.3 deprecation-2.1.0 esda-2.6.0 giddy-2.3.5 inequality-1.0.1 libpysal-4.12.1 llvmlite-0.43.0 mapclassify-2.8.1 mgwr-2.2.1 momepy-0.8.1 mpmath-1.3.0 numba-0.60.0 pointpats-2.5.1 pulp-2.9.0 pysal-24.7 quantecon-0.7.2 rasterstats-0.20.0 rtree-1.3.0 segregation-2.5 simplejson-3.19.3 soupsieve-2.6 spaghetti-1.7.6 spglm-1.1.0 spint-1.0.7 splot-1.1.7 spopt-0.6.1 spreg-1.7 spvcm-0.3.0 sympy-1.13.3 tobler-0.11.3

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\adm1\OneDrive - USherbrooke\Documents\memoire\py_madaclim\workdir\input\gbif_mada_available_caff_content_w_caffeine.csv")
df.drop(['specimen_id'], axis=1, inplace=True)
df
# Out:
#      longitude   latitude  caffeine_percent
# 0    43.797500 -22.875000              0.00
# 1    50.041667 -14.101389              0.03
# 2    46.333889 -24.560833              0.00
# 3    46.333889 -24.560833              0.00
# 4    46.333889 -24.560833              0.00
# ..         ...        ...               ...
# 521  47.000000 -23.000000              0.00
# 522  48.700000 -13.580000              0.00
# 523  49.700000 -13.180000              0.00
# 524  49.700000 -13.180000              0.00
# 525  44.580000 -22.920000              0.00
#
# [526 rows x 3 columns]

# %%
import geopandas as gpd
from libpysal.weights import DistanceBand

gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))

# Create a distance-based spatial weights matrix (e.g., 500km threshold)
w = DistanceBand.from_dataframe(gdf, threshold=500, binary=True)

# %%
import geopandas as gpd
import pandas as pd
from libpysal.weights import DistanceBand
from esda.getisord import G_Local
import matplotlib.pyplot as plt


# Perform Getis-Ord Gi* (local) analysis
g_star_local = G_Local(gdf['caffeine_percent'], w)

# Extract Z-scores from the result
gdf['Gi*'] = g_star_local.Zs  # These are the Z-scores for hot/cold spots

# Plot the Z-scores to visualize hotspots
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
gdf.plot(column='Gi*', ax=ax, legend=True, cmap='tab10', 
         legend_kwds={'label': "Getis-Ord Gi* Z-score"})

plt.title("Hotspot Analysis: Getis-Ord Gi* for Caffeine Content")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %%
from esda.moran import Moran_Local
from splot.esda import plot_moran_local

moran_local = Moran_Local(gdf['caffeine_percent'], w)
plot_moran_local(moran_local, gdf, p=0.05)
plt.title("Local Moran's I: Caffeine Content Clustering")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 2
#       1 from esda.moran import Moran_Local
# ----> 2 from splot.esda import plot_moran_local
#       4 moran_local = Moran_Local(gdf['caffeine_percent'], w)
#       5 plot_moran_local(moran_local, gdf, p=0.05)
#
# ImportError: cannot import name 'plot_moran_local' from 'splot.esda' (c:\Users\adm1\AppData\Local\Programs\Python\Python312\Lib\site-packages\splot\esda.py)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot KDE for caffeine content based on longitude and latitude
sns.kdeplot(x=gdf['longitude'], y=gdf['latitude'], shade=True, cmap='coolwarm')

plt.title("Kernel Density Estimation of Caffeine Content")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
# Out:
# C:\Users\adm1\AppData\Local\Temp\ipykernel_71736\751393209.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=gdf['longitude'], y=gdf['latitude'], shade=True, cmap='coolwarm')
# c:\Users\adm1\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\adm1\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import geopandas as gpd
from esda.moran import Moran_Local
from libpysal.weights import DistanceBand
import matplotlib.pyplot as plt

# Example DataFrame with longitude, latitude, and caffeine content
data = {
    'longitude': [43.5, 44.0, 45.0, 46.5],
    'latitude': [-25.0, -23.5, -20.5, -18.0],
    'caffeine_percent': [0.8, 0.5, 0.9, 1.1]
}

df = pd.DataFrame(data)

# Convert DataFrame to GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))

# Create spatial weights matrix (500 km distance threshold)
w = DistanceBand.from_dataframe(gdf, threshold=500, binary=True)

# Perform Local Moran's I
moran_local = Moran_Local(gdf['caffeine_percent'], w)

# Add Local Moran's I results to the GeoDataFrame
gdf['Is'] = moran_local.Is  # Local Moran's I values
gdf['p_sim'] = moran_local.p_sim  # P-values for significance
gdf['significant'] = gdf['p_sim'] < 0.05  # Boolean for significant areas

# Plot the Local Moran's I values (clusters of similarity)
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
gdf.plot(column='Is', ax=ax, cmap='coolwarm', legend=True,
         legend_kwds={'label': "Local Moran's I"})
plt.title("Local Moran's I for Caffeine Content")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %%
# !pip install splot esda libpysal

#"C:\Users\adm1\OneDrive - USherbrooke\Documents\memoire\data\madadata\gadm41_MDG_0.shp"

# %%
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Madagascar shapefile (assuming you have it as 'madagascar.shp')
# Replace with the path to your shapefile
              
# Set up the plot
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the Madagascar basemap
madagascar.plot(ax=ax, color='lightgray')

# Plot KDE for the caffeine content based on longitude and latitude
sns.kdeplot(x=df['longitude'], y=df['latitude'], 
            shade=True, cmap='coolwarm', ax=ax, alpha=0.5)

# Set the title and labels
plt.title("Kernel Density Estimation of Caffeine Content on Madagascar Map")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

# Show the plot
plt.show()
# Out:
# C:\Users\adm1\AppData\Local\Temp\ipykernel_71736\2734286857.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df['longitude'], y=df['latitude'],
# c:\Users\adm1\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\adm1\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import numpy as np
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
from shapely.geometry import Point
from scipy.stats import gaussian_kde

# Set up the plot
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the Madagascar basemap
madagascar = gpd.read_file(r"C:\Users\adm1\OneDrive - USherbrooke\Documents\memoire\data\madadata\gadm41_MDG_0.shp")
madagascar.plot(ax=ax, color='lightgray')

# Create grid points over the map area (covering the extent of Madagascar)
x_grid = np.linspace(madagascar.total_bounds[0], madagascar.total_bounds[2], 500)
y_grid = np.linspace(madagascar.total_bounds[1], madagascar.total_bounds[3], 500)
X, Y = np.meshgrid(x_grid, y_grid)
grid_points = np.vstack([X.ravel(), Y.ravel()])

# Calculate KDE using scipy's gaussian_kde
kde = gaussian_kde(np.vstack([df['longitude'], df['latitude']]))
Z = kde(grid_points).reshape(X.shape)

# Create a GeoDataFrame from grid points
grid_geom = [Point(x, y) for x, y in zip(X.ravel(), Y.ravel())]
grid_gdf = gpd.GeoDataFrame(geometry=grid_geom)

# Clip the KDE to the Madagascar boundary
clipped = gpd.clip(grid_gdf, madagascar)

# Plot the KDE within Madagascar's boundaries
ax.contourf(X, Y, Z, levels=100, cmap='coolwarm', alpha=0.5)

# Plot the Madagascar map boundaries again to make sure they're on top
madagascar.boundary.plot(ax=ax, linewidth=1, color='black')

# Set title and labels
#plt.title("KDE of Caffeine Content Clipped to Madagascar")
plt.xlabel("Longitude", fontsize=20)
plt.ylabel("Latitude", fontsize=20)

# Show the plot
plt.show()
# Out:
# C:\Users\adm1\AppData\Local\Temp\ipykernel_6332\3263268933.py:30: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   clipped = gpd.clip(grid_gdf, madagascar)

# %%
# !pip install SALib
# Out:
# Collecting SALib
#   Downloading salib-1.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib>=3.5 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from SALib) (3.9.0)
# Collecting multiprocess (from SALib)
#   Downloading multiprocess-0.70.17-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from SALib) (2.0.0)
# Requirement already satisfied: pandas>=2.0 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from SALib) (2.2.2)
# Requirement already satisfied: scipy>=1.9.3 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from SALib) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.5->SALib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.5->SALib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.5->SALib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.5->SALib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\adm1\appdata\roaming\python\python312\site-packages (from matplotlib>=3.5->SALib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.5->SALib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.5->SALib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adm1\appdata\roaming\python\python312\site-packages (from matplotlib>=3.5->SALib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0->SALib) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adm1\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0->SALib) (2024.1)
# Collecting dill>=0.3.9 (from multiprocess->SALib)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.5 in c:\users\adm1\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.5->SALib) (1.16.0)
# Downloading salib-1.5.1-py3-none-any.whl (778 kB)
#    ---------------------------------------- 0.0/778.9 kB ? eta -:--:--
#    ---------------------------------------- 778.9/778.9 kB 8.3 MB/s eta 0:00:00
# Downloading multiprocess-0.70.17-py312-none-any.whl (147 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
# Installing collected packages: dill, multiprocess, SALib
# Successfully installed SALib-1.5.1 dill-0.3.9 multiprocess-0.70.17

# %%
from sklearn.ensemble import RandomForestRegressor
import numpy as np
from SALib.sample import saltelli

# Define your problem with input variables
problem = {
    'num_vars': 3,  # Three input variables
    'names': ['temperature', 'rainfall', 'soil_pH'],  # Variable names
    'bounds': [[10, 30],  # temperature range
               [500, 2000],  # rainfall range
               [4, 8]]  # soil pH range
}

# Generate sample points using Sobol's method
param_values = saltelli.sample(problem, 1000)

# Assuming you have a pre-trained RandomForest model
# 'model' is your trained RandomForest model
model = RandomForestRegressor()
# You should have already trained your model on some data

# Reshape param_values for prediction (each row is a sample)
Y = model.predict(param_values)

# Y now contains the predicted caffeine content for each sample
# Out:
# C:\Users\adm1\AppData\Local\Temp\ipykernel_71736\4107025840.py:15: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5.1 Please use `salib.sample.sobol`
#   param_values = saltelli.sample(problem, 1000)
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[30], line 23
#      19 model = RandomForestRegressor()
#      20 # You should have already trained your model on some data
#      21
#      22 # Reshape param_values for prediction (each row is a sample)
# ---> 23 Y = model.predict(param_values)
#      25 # Y now contains the predicted caffeine content for each sample
#
# File c:\Users\adm1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:1061, in ForestRegressor.predict(self, X)
#    1042 def predict(self, X):
#    1043     """
#    1044     Predict regression target for X.
#    1045
#    (...)
#    1059         The predicted values.
#    1060     """
# -> 1061     check_is_fitted(self)
#    1062     # Check data
#    1063     X = self._validate_X_predict(X)
#
# File c:\Users\adm1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1661, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1658     raise TypeError("%s is not an estimator instance." % (estimator))
#    1660 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1661     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This RandomForestRegressor instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
from SALib.sample import saltelli
from SALib.analyze import sobol
import numpy as np

# Define the problem: input variables and their ranges
problem = {
    'num_vars': 3,  # number of input variables
    'names': ['temperature', 'rainfall', 'soil_pH'],  # variable names
    'bounds': [[10, 30],  # temperature bounds
               [500, 2000],  # rainfall bounds
               [4, 8]]  # soil pH bounds
}

# Generate sample points for the sensitivity analysis
param_values = saltelli.sample(problem, 1000)

# Run the model on each sample (replace 'model' with your predictive model)
#Y = np.array([model(x) for x in param_values])


# Perform Sobol Sensitivity Analysis
Si = sobol.analyze(problem, Y)

# Print first-order sensitivities
print("First-order effects:", Si['S1'])
# Out:
# C:\Users\adm1\AppData\Local\Temp\ipykernel_71736\3030973858.py:15: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5.1 Please use `salib.sample.sobol`
#   param_values = saltelli.sample(problem, 1000)
# c:\Users\adm1\AppData\Local\Programs\Python\Python312\Lib\site-packages\SALib\sample\saltelli.py:110: UserWarning:
#         Convergence properties of the Sobol' sequence is only valid if
#         `N` (1000) is equal to `2^n`.
#
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 18
#      15 param_values = saltelli.sample(problem, 1000)
#      17 # Run the model on each sample (replace 'model' with your predictive model)
# ---> 18 Y = np.array([model(x) for x in param_values])
#      20 # Perform Sobol Sensitivity Analysis
#      21 Si = sobol.analyze(problem, Y)
#
# NameError: name 'model' is not defined
