# %%
import sklearn
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
coffea_orig = pd.read_csv(r"..\input\project_input_nonbin.csv")

# %%
coffea_orig.describe()
# Out:
#        source_crs   longitude    latitude  sampled_layers  nodata_layers  \
# count       189.0  189.000000  189.000000           189.0     189.000000
# mean       4326.0   48.658536  -15.003286            79.0       0.492063
# std           0.0    1.128089    4.357381             0.0       5.765469
# min        4326.0   44.732222  -24.842778            79.0       0.000000
# 25%        4326.0   49.065830  -14.221940            79.0       0.000000
# 50%        4326.0   49.150000  -12.846388            79.0       0.000000
# 75%        4326.0   49.174722  -12.530000            79.0       0.000000
# max        4326.0   49.985833  -12.310000            79.0      79.000000
#
#             tmin1       tmin2       tmin3       tmin4       tmin5  ...  \
# count  188.000000  188.000000  188.000000  188.000000  188.000000  ...
# mean   168.148936  195.585106  194.787234  187.914894  169.659574  ...
# std     27.834291   25.327126   25.251197   25.187281   26.873462  ...
# ...

# %%
coffea_orig.shape
# Out:
# (189, 89)

# %%
coffea = coffea_orig.copy()
coffea.drop(columns=['source_crs', 'mada_geom_point', 'sampled_layers', 'nodata_layers', 'is_categorical_encoded', 'genus', 'species'],inplace=True)

# %%
coffea
# Out:
#     specimen_id  longitude   latitude  tmin1  tmin2  tmin3  tmin4  tmin5  \
# 0     spe1_duba  49.213056 -12.479722  175.0  199.0  200.0  196.0  183.0
# 1     spe1_auga  49.213056 -12.479722  175.0  199.0  200.0  196.0  183.0
# 2     spe1_moge  49.166389 -12.524444  144.0  170.0  171.0  167.0  153.0
# 3     spe2_auga  49.213056 -12.479722  175.0  199.0  200.0  196.0  183.0
# 4     spe2_duba  49.083333 -12.900000  208.0  227.0  229.0  225.0  211.0
# ..          ...        ...        ...    ...    ...    ...    ...    ...
# 184  spe65_moge  49.180000 -12.530000  145.0  173.0  173.0  169.0  155.0
# 185  spe66_moge  49.180000 -12.530000  145.0  173.0  173.0  169.0  155.0
# 186  spe76_duba  49.700000 -13.180000  200.0  225.0  222.0  219.0  204.0
# 187  spe77_duba  49.700000 -13.180000  200.0  225.0  222.0  219.0  204.0
# 188  spe67_moge  49.166670 -12.516670  147.0  173.0  173.0  170.0  156.0
#
#      tmin6  tmin7  ...  ndm_year  altitude  slope  aspect  solrad  rock_types  \
# ...
