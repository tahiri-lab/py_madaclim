# %%
import pandas as pd
from pathlib import Path
import json
import re

from coffeaphylogeo.definitions import Definitions

# %%
defs = Definitions()
defs.root_dir
# Out:
# PosixPath('/home/local/USHERBROOKE/lals2906/programming/python_projects/coffeaPhyloGeo')

# %%
defs.geoclim_dirs
# Out:
# {'main': 'geoclim',
#  'gps_data': 'geospatial',
#  'climate_data': 'climate',
#  'environment_data': 'enviro'}

# %%
climate_dir = defs.get_geoclim_path("climate_data")
enviro_dir = defs.get_geoclim_path("environment_data")

# %%
print(climate_dir)
print(enviro_dir)
# Out:
# /home/local/USHERBROOKE/lals2906/programming/python_projects/coffeaPhyloGeo/data/geoclim/climate
# /home/local/USHERBROOKE/lals2906/programming/python_projects/coffeaPhyloGeo/data/geoclim/enviro

# %%
defs.geoclim_files
# Out:
# {'raw_table': 'coff_madag_species_summary.xlsx',
#  'gps_all': 'species_locations_all_positions.csv',
#  'gbs_filtered': 'species_locations_gbs_only.csv',
#  'madaclim_current': 'madaclim_current.tif',
#  'madaclim_enviro': 'madaclim_enviro.tif',
#  'clim_metadata': 'clim_metadata.json',
#  'env_metadata': 'enviro_metadata.json',
#  'clim_data_format': 'clim_data_format.json',
#  'env_data_format': 'env_data_format.json'}

# %%
with open(climate_dir / defs.geoclim_files["clim_data_format"], "r") as f:
    data_format = json.load(f)

# %%
df = pd.read_json(data_format["table_0"])
df
# Out:
#   Layers                                   Climate variable
# 0   1-12              Monthly minimum temperature (°C x 10)
# 1  13-24              Monthly maximum temperature (°C x 10)
# 2  25-36           Monthly total precipitation (mm.month-1)
# 3  37-55                    Bioclimatic variables (bioclim)
# 4  56-67  Monthly potential evapotranspiration (mm.month-1)
# 5     68           Annual potential evapotranspiration (mm)
# 6     69                 Annual climatic water deficit (mm)
# 7     70                   Number of dry months in the year

# %%
# Split 'Layers' column and create new rows
def split_layers(row):
    if '-' in row['Layers']:
        start, end = map(int, row['Layers'].split('-'))
        return pd.Series(row['Climate variable'], index=range(start, end+1))
    else:
        return pd.Series(row['Climate variable'], index=[int(row['Layers'])])

df = df.apply(split_layers, axis=1).stack().reset_index().drop(columns="level_0")
df.columns = ['layer_number', 'climate_variable']

# %%
df["data_type"] = "clim"

# %%
df["layer_name"] = ""

# %%
df
# Out:
#     layer_number                                   climate_variable data_type  \
# 0              1              Monthly minimum temperature (°C x 10)      clim
# 1              2              Monthly minimum temperature (°C x 10)      clim
# 2              3              Monthly minimum temperature (°C x 10)      clim
# 3              4              Monthly minimum temperature (°C x 10)      clim
# 4              5              Monthly minimum temperature (°C x 10)      clim
# ..           ...                                                ...       ...
# 65            66  Monthly potential evapotranspiration (mm.month-1)      clim
# 66            67  Monthly potential evapotranspiration (mm.month-1)      clim
# 67            68           Annual potential evapotranspiration (mm)      clim
# 68            69                 Annual climatic water deficit (mm)      clim
# 69            70                   Number of dry months in the year      clim
#
#    layer_name
# 0
# 1
# 2
# 3
# 4
# ..        ...
# 65
# 66
# 67
# 68
# 69
#
# [70 rows x 4 columns]

# %%
with open(climate_dir /  defs.geoclim_files["clim_metadata"],"r") as f:
    data_metadata = json.load(f)

# %%
monthly_vars = pd.read_json(data_metadata["table_0"])

# %%
monthly_vars.columns = ["layer_name", "description"]

# %%
monthly_vars
# Out:
#   layer_name                               description
# 0   tmin1-12     Monthly minimum temperature (°C x 10)
# 1   tmax1-12     Monthly maximum temperature (°C x 10)
# 2   prec1-12  Monthly total precipitation (mm.month-1)

# %%
# Split 'Layers' column and create new rows
def split_repeating_vars(row, col_to_split, col_to_keep):
    
    # Extract the range and layername to a new smaller df of len(range(start, end))
    if "-" in row[col_to_split]:
        start = int(re.search("\d+", row[col_to_split].split("-")[0]).group())
        end = int(row[col_to_split].split("-")[1])
        name = re.search("[a-z]*", row[col_to_split]).group()
                
        # Create a DataFrame with the split values and the description column
        df = pd.DataFrame({col_to_split: [f"{name}{month}" for month in range(start, end+1)],
                           col_to_keep: row[col_to_keep]})
        return df
    
    # When no changes to changes to row
    else:
        df = pd.DataFrame({col_to_split: [row[col_to_split]], col_to_keep: [row[col_to_keep]]})
        return df

# %%
new_monthly = pd.concat(monthly_vars.apply(split_repeating_vars, axis=1, args=("layer_name", "description", )).to_list(), ignore_index=True)

# %%
pd.merge(df, new_monthly, left_on='climate_variable', right_on='description').groupby(['climate_variable', 'description']).head(12)
# Out:
#      layer_number                          climate_variable data_type  \
# 0               1     Monthly minimum temperature (°C x 10)      clim
# 1               1     Monthly minimum temperature (°C x 10)      clim
# 2               1     Monthly minimum temperature (°C x 10)      clim
# 3               1     Monthly minimum temperature (°C x 10)      clim
# 4               1     Monthly minimum temperature (°C x 10)      clim
# 5               1     Monthly minimum temperature (°C x 10)      clim
# 6               1     Monthly minimum temperature (°C x 10)      clim
# 7               1     Monthly minimum temperature (°C x 10)      clim
# 8               1     Monthly minimum temperature (°C x 10)      clim
# 9               1     Monthly minimum temperature (°C x 10)      clim
# 10              1     Monthly minimum temperature (°C x 10)      clim
# 11              1     Monthly minimum temperature (°C x 10)      clim
# 144            13     Monthly maximum temperature (°C x 10)      clim
# 145            13     Monthly maximum temperature (°C x 10)      clim
# 146            13     Monthly maximum temperature (°C x 10)      clim
# 147            13     Monthly maximum temperature (°C x 10)      clim
# 148            13     Monthly maximum temperature (°C x 10)      clim
# 149            13     Monthly maximum temperature (°C x 10)      clim
# 150            13     Monthly maximum temperature (°C x 10)      clim
# 151            13     Monthly maximum temperature (°C x 10)      clim
# 152            13     Monthly maximum temperature (°C x 10)      clim
# 153            13     Monthly maximum temperature (°C x 10)      clim
# 154            13     Monthly maximum temperature (°C x 10)      clim
# 155            13     Monthly maximum temperature (°C x 10)      clim
# 288            25  Monthly total precipitation (mm.month-1)      clim
# 289            25  Monthly total precipitation (mm.month-1)      clim
# 290            25  Monthly total precipitation (mm.month-1)      clim
# 291            25  Monthly total precipitation (mm.month-1)      clim
# 292            25  Monthly total precipitation (mm.month-1)      clim
# 293            25  Monthly total precipitation (mm.month-1)      clim
# 294            25  Monthly total precipitation (mm.month-1)      clim
# 295            25  Monthly total precipitation (mm.month-1)      clim
# 296            25  Monthly total precipitation (mm.month-1)      clim
# 297            25  Monthly total precipitation (mm.month-1)      clim
# 298            25  Monthly total precipitation (mm.month-1)      clim
# 299            25  Monthly total precipitation (mm.month-1)      clim
#
#     layer_name_x layer_name_y                               description
# 0                       tmin1     Monthly minimum temperature (°C x 10)
# 1                       tmin2     Monthly minimum temperature (°C x 10)
# 2                       tmin3     Monthly minimum temperature (°C x 10)
# 3                       tmin4     Monthly minimum temperature (°C x 10)
# 4                       tmin5     Monthly minimum temperature (°C x 10)
# 5                       tmin6     Monthly minimum temperature (°C x 10)
# 6                       tmin7     Monthly minimum temperature (°C x 10)
# 7                       tmin8     Monthly minimum temperature (°C x 10)
# 8                       tmin9     Monthly minimum temperature (°C x 10)
# 9                      tmin10     Monthly minimum temperature (°C x 10)
# 10                     tmin11     Monthly minimum temperature (°C x 10)
# 11                     tmin12     Monthly minimum temperature (°C x 10)
# 144                     tmax1     Monthly maximum temperature (°C x 10)
# 145                     tmax2     Monthly maximum temperature (°C x 10)
# 146                     tmax3     Monthly maximum temperature (°C x 10)
# 147                     tmax4     Monthly maximum temperature (°C x 10)
# 148                     tmax5     Monthly maximum temperature (°C x 10)
# 149                     tmax6     Monthly maximum temperature (°C x 10)
# 150                     tmax7     Monthly maximum temperature (°C x 10)
# 151                     tmax8     Monthly maximum temperature (°C x 10)
# 152                     tmax9     Monthly maximum temperature (°C x 10)
# 153                    tmax10     Monthly maximum temperature (°C x 10)
# 154                    tmax11     Monthly maximum temperature (°C x 10)
# 155                    tmax12     Monthly maximum temperature (°C x 10)
# 288                     prec1  Monthly total precipitation (mm.month-1)
# 289                     prec2  Monthly total precipitation (mm.month-1)
# 290                     prec3  Monthly total precipitation (mm.month-1)
# 291                     prec4  Monthly total precipitation (mm.month-1)
# 292                     prec5  Monthly total precipitation (mm.month-1)
# 293                     prec6  Monthly total precipitation (mm.month-1)
# 294                     prec7  Monthly total precipitation (mm.month-1)
# 295                     prec8  Monthly total precipitation (mm.month-1)
# 296                     prec9  Monthly total precipitation (mm.month-1)
# 297                    prec10  Monthly total precipitation (mm.month-1)
# 298                    prec11  Monthly total precipitation (mm.month-1)
# 299                    prec12  Monthly total precipitation (mm.month-1)

# %%
pd.merge(df, new_monthly, how="inner", left_on="climate_variable", right_on="description").head()
# Out:
#    layer_number                       climate_variable data_type layer_name_x  \
# 0             1  Monthly minimum temperature (°C x 10)      clim
# 1             1  Monthly minimum temperature (°C x 10)      clim
# 2             1  Monthly minimum temperature (°C x 10)      clim
# 3             1  Monthly minimum temperature (°C x 10)      clim
# 4             1  Monthly minimum temperature (°C x 10)      clim
#
#   layer_name_y                            description
# 0        tmin1  Monthly minimum temperature (°C x 10)
# 1        tmin2  Monthly minimum temperature (°C x 10)
# 2        tmin3  Monthly minimum temperature (°C x 10)
# 3        tmin4  Monthly minimum temperature (°C x 10)
# 4        tmin5  Monthly minimum temperature (°C x 10)

# %%
df[df["layer_number"].between(37, 55)]
# Out:
#     layer_number                 climate_variable data_type layer_name
# 36            37  Bioclimatic variables (bioclim)      clim
# 37            38  Bioclimatic variables (bioclim)      clim
# 38            39  Bioclimatic variables (bioclim)      clim
# 39            40  Bioclimatic variables (bioclim)      clim
# 40            41  Bioclimatic variables (bioclim)      clim
# 41            42  Bioclimatic variables (bioclim)      clim
# 42            43  Bioclimatic variables (bioclim)      clim
# 43            44  Bioclimatic variables (bioclim)      clim
# 44            45  Bioclimatic variables (bioclim)      clim
# 45            46  Bioclimatic variables (bioclim)      clim
# 46            47  Bioclimatic variables (bioclim)      clim
# 47            48  Bioclimatic variables (bioclim)      clim
# 48            49  Bioclimatic variables (bioclim)      clim
# 49            50  Bioclimatic variables (bioclim)      clim
# 50            51  Bioclimatic variables (bioclim)      clim
# 51            52  Bioclimatic variables (bioclim)      clim
# 52            53  Bioclimatic variables (bioclim)      clim
# 53            54  Bioclimatic variables (bioclim)      clim
# 54            55  Bioclimatic variables (bioclim)      clim
